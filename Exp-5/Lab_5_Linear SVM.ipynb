# %%
#Data Pre-processing Step
# importing libraries & datasets
from sklearn import *
import numpy as nm
import matplotlib.pyplot as mtp
import pandas as pd
data_set= pd.read_csv('Data_Exp6.csv')
data_set
# Out:
#     Rectal Pain  Sore Throat  Swollen Tonsils  HIV Infection MonkeyPox
# 0         False         True             True          False  Negative
# 1          True        False            False           True  Positive
# 2         False         True            False           True  Positive
# 3          True        False             True           True  Positive
# 4          True         True             True           True  Positive
# 5         False         True            False          False  Negative
# 6         False         True            False           True  Positive
# 7          True         True             True          False  Positive
# 8         False         True            False          False  Positive
# 9         False        False            False           True  Negative
# 10        False         True             True          False  Negative
# 11         True         True            False          False  Negative
# ...

# %%
feature_cols = ['Rectal Pain', 'Sore Throat', 'Swollen Tonsils', 'HIV Infection']
x = data_set[feature_cols] # Features
y = data_set.MonkeyPox # Target variable

# %%
# Splitting the dataset into training and test set.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size= 0.01,random_state=0)
from sklearn.preprocessing import StandardScaler
st_x= StandardScaler()
x_train= st_x.fit_transform(x_train)
x_test= st_x.transform(x_test)

# %%
from sklearn.svm import SVC # "Support vector classifier"
classifier = SVC(kernel='linear', random_state=0)
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
# %%capture --no-display
from matplotlib.colors import ListedColormap
x_set, y_set = x_train, y_train
x1,x2=nm.meshgrid(nm.arange(start=x_set[:,0].min()- 1,stop=x_set[:,0].max()+1,step=0.01),
                  nm.arange(start = x_set[:, 1].min() - 1, 
                            stop = x_set[:, 1].max() + 1, step = 0.01))
mtp.contourf(x1,x2,
             classifier.predict(nm.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
mtp.xlim(x1.min(), x1.max())
mtp.ylim(x2.min(), x2.max())
for i, j in enumerate(nm.unique(y_set)):
    mtp.scatter(x_set[y_set==j,0],x_set[y_set==j,1],
                c=ListedColormap(('red','green'))(i),label=j)
mtp.title('Linear SVM classifier')
mtp.xlabel('Age')
mtp.ylabel('Estimated Salary')
mtp.legend()
mtp.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 6>()
#       2 x_set, y_set = x_train, y_train
#       3 x1,x2=nm.meshgrid(nm.arange(start=x_set[:,0].min()- 1,stop=x_set[:,0].max()+1,step=0.01),
#       4                   nm.arange(start = x_set[:, 1].min() - 1,
#       5                             stop = x_set[:, 1].max() + 1, step = 0.01))
#       6 mtp.contourf(x1,x2,
# ----> 7              classifier.predict(nm.array([x1.ravel(),x2.ravel()]).T).reshape(x1.shape),
#       8              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
#       9 mtp.xlim(x1.min(), x1.max())
#      10 mtp.ylim(x2.min(), x2.max())
#
# File ~\anaconda3\lib\site-packages\sklearn\svm\_base.py:791, in BaseSVC.predict(self, X)
#     789     y = np.argmax(self.decision_function(X), axis=1)
#     790 else:
# --> 791     y = super().predict(X)
# ...
